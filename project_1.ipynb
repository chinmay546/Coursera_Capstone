# %% [markdown]
# Imported Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Converted the  our Dataset into DataFrame

# %%
df = pd.read_csv('hospital-locations.csv')

# %% [markdown]
# Here's Our Column from the dataset

# %%
df.columns
# Out:
# Index(['NAME', 'AD', 'ZIPCODE', 'NEIGH', 'XCOORD', 'YCOORD', 'Location'], dtype='object')

# %%
df
# Out:
#                                              NAME                    AD  \
# 0                        Lemuel Shattuck Hospital         170 MORTON ST
# 1   Beth Israel Deaconess Medical Center East Cam      330 BROOKLINE AV
# 2                        Jewish Memorial Hospital        59 TOWNSEND ST
# 3                    New England Baptist Hospital    125 PARKER HILL AV
# 4      Boston Specialty & Rehabilitation Hospital          249 RIVER ST
# 5                           Boston Medical Center     88 EAST NEWTON ST
# 6                                     Va Hospital    125 PARKER HILL AV
# 7               Massachusetts Eye & Ear Infirmary        243 CHARLES ST
# 8                                Kindred Hospital  1515 COMMONWEALTH AV
# 9                    Brigham And Women's Hospital         75 FRANCIS ST
# 10                                Carney Hospital    2100 DORCHESTER AV
# 11                     New England Medical Center     750 WASHINGTON ST
# ...

# %% [markdown]
# As , We can see , col named XCOORD and YCOORD contain the co-ordinates of the particular hospitals , so lets shift the decimal point

# %%
df['XCOORD'] = df['XCOORD']/1000000

# %%
df['YCOORD'] = df['YCOORD']/1000000

# %%
df
# Out:
#                                              NAME                    AD  \
# 0                        Lemuel Shattuck Hospital         170 MORTON ST
# 1   Beth Israel Deaconess Medical Center East Cam      330 BROOKLINE AV
# 2                        Jewish Memorial Hospital        59 TOWNSEND ST
# 3                    New England Baptist Hospital    125 PARKER HILL AV
# 4      Boston Specialty & Rehabilitation Hospital          249 RIVER ST
# 5                           Boston Medical Center     88 EAST NEWTON ST
# 6                                     Va Hospital    125 PARKER HILL AV
# 7               Massachusetts Eye & Ear Infirmary        243 CHARLES ST
# 8                                Kindred Hospital  1515 COMMONWEALTH AV
# 9                    Brigham And Women's Hospital         75 FRANCIS ST
# 10                                Carney Hospital    2100 DORCHESTER AV
# 11                     New England Medical Center     750 WASHINGTON ST
# ...

# %% [markdown]
# We can observe , dataset contain some missing values  , so lets drop it

# %%
df.dropna(axis=0 , inplace = True)

# %%
df['YCOORD'] = df['YCOORD'] * -1

# %% [markdown]
# This will be our final data

# %%
df
# Out:
#                                              NAME                    AD  \
# 0                        Lemuel Shattuck Hospital         170 MORTON ST
# 1   Beth Israel Deaconess Medical Center East Cam      330 BROOKLINE AV
# 2                        Jewish Memorial Hospital        59 TOWNSEND ST
# 3                    New England Baptist Hospital    125 PARKER HILL AV
# 4      Boston Specialty & Rehabilitation Hospital          249 RIVER ST
# 5                           Boston Medical Center     88 EAST NEWTON ST
# 6                                     Va Hospital    125 PARKER HILL AV
# 7               Massachusetts Eye & Ear Infirmary        243 CHARLES ST
# 8                                Kindred Hospital  1515 COMMONWEALTH AV
# 9                    Brigham And Women's Hospital         75 FRANCIS ST
# 10                                Carney Hospital    2100 DORCHESTER AV
# 11                     New England Medical Center     750 WASHINGTON ST
# ...

# %%
from haversine import haversine, Unit

# %%
lyon = (71.074854,-42.335459) # (lat, lon)
a = float(input('Enter Latitude '))
b = float(input('Enter Longitude '))
c= []
c.append(a)
c.append(b)
c = tuple(c)
d=[]
df1 = pd.DataFrame()
dist = []
for ind in df.index:
    x = df['XCOORD'][ind]
    y = df['YCOORD'][ind]
    d.append(x)
    d.append(y)
    d = tuple(d)
    dist.append(haversine(c,d))
    d = list(d)
    d.clear()
# Out:
# Enter Latitude 71.072040
# Enter Longitude -42.336860

# %%
df['Distance'] = dist

# %%
df
# Out:
#                                              NAME                    AD  \
# 0                        Lemuel Shattuck Hospital         170 MORTON ST
# 1   Beth Israel Deaconess Medical Center East Cam      330 BROOKLINE AV
# 2                        Jewish Memorial Hospital        59 TOWNSEND ST
# 3                    New England Baptist Hospital    125 PARKER HILL AV
# 4      Boston Specialty & Rehabilitation Hospital          249 RIVER ST
# 5                           Boston Medical Center     88 EAST NEWTON ST
# 6                                     Va Hospital    125 PARKER HILL AV
# 7               Massachusetts Eye & Ear Infirmary        243 CHARLES ST
# 8                                Kindred Hospital  1515 COMMONWEALTH AV
# 9                    Brigham And Women's Hospital         75 FRANCIS ST
# 10                                Carney Hospital    2100 DORCHESTER AV
# 11                     New England Medical Center     750 WASHINGTON ST
# ...

# %%
df[df['Distance'] == min(df['Distance'])]
# Out:
#                     NAME                 AD  ZIPCODE      NEIGH     XCOORD  \
# 5  Boston Medical Center  88 EAST NEWTON ST     2118  SOUTH END  71.072029
#
#       YCOORD                                           Location  Distance
# 5 -42.336883  88 EAST NEWTON ST\nSOUTH END, MA 02118\n(42.33...  0.001478
