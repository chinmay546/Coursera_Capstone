# %% [markdown]
# Lets Start with importing dataset

# %%
import pandas as pd

# %% [markdown]
# Converting our dataset into dataframe

# %%
df = pd.read_csv('hospital-locations.csv')

# %%
df
# Out:
#                                              NAME                    AD  \
# 0                        Lemuel Shattuck Hospital         170 MORTON ST
# 1   Beth Israel Deaconess Medical Center East Cam      330 BROOKLINE AV
# 2                        Jewish Memorial Hospital        59 TOWNSEND ST
# 3                    New England Baptist Hospital    125 PARKER HILL AV
# 4      Boston Specialty & Rehabilitation Hospital          249 RIVER ST
# 5                           Boston Medical Center     88 EAST NEWTON ST
# 6                                     Va Hospital    125 PARKER HILL AV
# 7               Massachusetts Eye & Ear Infirmary        243 CHARLES ST
# 8                                Kindred Hospital  1515 COMMONWEALTH AV
# 9                    Brigham And Women's Hospital         75 FRANCIS ST
# 10                                Carney Hospital    2100 DORCHESTER AV
# 11                     New England Medical Center     750 WASHINGTON ST
# ...

# %% [markdown]
# Col 'XCOORD' and 'YCOORD' contains the co-ordinates , lets shift its decimal point

# %%
df['XCOORD'] = df['XCOORD']/1000000

# %%
df['YCOORD'] = df['YCOORD']/1000000

# %%
df.head()
# Out:
#                                             NAME                  AD  ZIPCODE  \
# 0                       Lemuel Shattuck Hospital       170 MORTON ST     2130
# 1  Beth Israel Deaconess Medical Center East Cam    330 BROOKLINE AV     2115
# 2                       Jewish Memorial Hospital      59 TOWNSEND ST     2119
# 3                   New England Baptist Hospital  125 PARKER HILL AV     2120
# 4     Boston Specialty & Rehabilitation Hospital        249 RIVER ST     2126
#
#             NEIGH     XCOORD     YCOORD  \
# 0      ROSLINDALE  71.106033  42.300022
# 1  FENWAY/KENMORE  71.106780  42.339726
# 2         ROXBURY  71.092712  42.318569
# 3   JAMAICA PLAIN  71.107615  42.329944
# 4        MATTAPAN  71.081888  42.271300
#
#                                             Location
# 0  170 MORTON ST\nROSLINDALE, MA 02130\n(42.30025...
# 1  330 BROOKLINE AV\nFENWAY/KENMORE, MA 02115\n(4...
# 2  59 TOWNSEND ST\nROXBURY, MA 02119\n(42.3185628...
# ...

# %% [markdown]
# Dataset contains some missing value , lets drop it

# %%
df.dropna(axis = 0 , inplace = True)

# %%
df
# Out:
#                                              NAME                    AD  \
# 0                        Lemuel Shattuck Hospital         170 MORTON ST
# 1   Beth Israel Deaconess Medical Center East Cam      330 BROOKLINE AV
# 2                        Jewish Memorial Hospital        59 TOWNSEND ST
# 3                    New England Baptist Hospital    125 PARKER HILL AV
# 4      Boston Specialty & Rehabilitation Hospital          249 RIVER ST
# 5                           Boston Medical Center     88 EAST NEWTON ST
# 6                                     Va Hospital    125 PARKER HILL AV
# 7               Massachusetts Eye & Ear Infirmary        243 CHARLES ST
# 8                                Kindred Hospital  1515 COMMONWEALTH AV
# 9                    Brigham And Women's Hospital         75 FRANCIS ST
# 10                                Carney Hospital    2100 DORCHESTER AV
# 11                     New England Medical Center     750 WASHINGTON ST
# ...

# %% [markdown]
# Final DataFrame
